# %% [markdown]
# <a href="https://colab.research.google.com/github/atmakurinikitha2005-unqe/Gen-AI/blob/main/NLP_Preprocessing_Engine_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Conceptual Understanding

# %%
print("1. Difference between 'Love' and 'love':")
print("They are treated as different tokens unless converted to lowercase.")
print("Converting to lowercase ensures both are treated the same -> improves consistency.\n")

print("2. If stopwords are not removed:")
print("They increase noise and reduce model efficiency.\n")

print("3. When removing stopwords is harmful:")
print("- Sentiment Analysis (e.g., 'not happy')")
print("- Question answering systems\n")

print("4. Stemming vs Lemmatization:")
print("Stemming cuts words and may produce incorrect forms.")
print("Lemmatization returns meaningful root words.\n")
# Out:
# 1. Difference between 'Love' and 'love':
# They are treated as different tokens unless converted to lowercase.
# Converting to lowercase ensures both are treated the same -> improves consistency.
#
# 2. If stopwords are not removed:
# They increase noise and reduce model efficiency.
#
# 3. When removing stopwords is harmful:
# - Sentiment Analysis (e.g., 'not happy')
# - Question answering systems
#
# 4. Stemming vs Lemmatization:
# Stemming cuts words and may produce incorrect forms.
# Lemmatization returns meaningful root words.

# %% [markdown]
# # Task 2:Build Advanced Preprocessing Function

# %%
import re

def preprocess_text(text):
    # Handle empty or invalid input
    if not text or not isinstance(text, str):
        return [], ""

    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r"http\S+|www\S+", "", text)

    # Remove emails
    text = re.sub(r"\S+@\S+", "", text)

    # Remove numbers
    text = re.sub(r"\d+", "", text)

    # Handle repeated characters (soooo -> soo)
    text = re.sub(r"(.)\1{2,}", r"\1\1", text)

    # Remove special characters and emojis
    text = re.sub(r"[^\w\s]", "", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    # Tokenization
    tokens = text.split()

    # Remove short tokens (<=2) except 'no', 'not'
    tokens = [w for w in tokens if len(w) > 2 or w in ["no", "not"]]

    # Final cleaned sentence
    cleaned_sentence = " ".join(tokens)

    return tokens, cleaned_sentence


text = "Get 100% FREE access now!!!"

tokens, clean = preprocess_text(text)

print("Original Text:", text)
print("Cleaned Tokens:", tokens)
print("Cleaned Sentence:", clean)
# Out:
# Original Text: Get 100% FREE access now!!!
# Cleaned Tokens: ['get', 'free', 'access', 'now']
# Cleaned Sentence: get free access now

# %% [markdown]
# # Task 3: Stress Testing

# %%
test_sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

results = []

print("===== Stress Testing Output =====\n")

for text in test_sentences:
    tokens, clean = preprocess_text(text)
    results.append((text, tokens, clean))

    print("Original Text:", text)
    print("Cleaned Tokens:", tokens)
    print("Cleaned Sentence:", clean)
    print("-"*50)
# Out:
# ===== Stress Testing Output =====
#
# Original Text: Get 100% FREE access now!!!
# Cleaned Tokens: ['get', 'free', 'access', 'now']
# Cleaned Sentence: get free access now
# --------------------------------------------------
# Original Text: I absolutely looooved this product 😍😍
# Cleaned Tokens: ['absolutely', 'looved', 'this', 'product']
# Cleaned Sentence: absolutely looved this product
# --------------------------------------------------
# Original Text: Worst service ever... 0/10
# Cleaned Tokens: ['worst', 'service', 'ever']
# Cleaned Sentence: worst service ever
# --------------------------------------------------
# Original Text: Call me at 9876543210
# Cleaned Tokens: ['call']
# Cleaned Sentence: call
# --------------------------------------------------
# Original Text: This is THE best course!!!
# Cleaned Tokens: ['this', 'the', 'best', 'course']
# Cleaned Sentence: this the best course
# --------------------------------------------------
# ...

# %% [markdown]
# # Task 4: Token Analytics

# %%
print("\n===== Token Analytics =====\n")

for text, tokens, clean in results:
    total = len(tokens)
    unique = len(set(tokens))
    avg = np.mean([len(t) for t in tokens]) if tokens else 0

    print("Sentence:", text)
    print("Total Tokens:", total)
    print("Unique Tokens:", unique)
    print("Average Token Length:", round(avg, 2))
    print("-"*50)
# Out:
# ===== Token Analytics =====
#
# Sentence: Get 100% FREE access now!!!
# Total Tokens: 4
# Unique Tokens: 4
# Average Token Length: 4.0
# --------------------------------------------------
# Sentence: I absolutely looooved this product 😍😍
# Total Tokens: 4
# Unique Tokens: 4
# Average Token Length: 6.75
# --------------------------------------------------
# Sentence: Worst service ever... 0/10
# Total Tokens: 3
# Unique Tokens: 3
# Average Token Length: 5.33
# --------------------------------------------------
# Sentence: Call me at 9876543210
# Total Tokens: 1
# Unique Tokens: 1
# Average Token Length: 4.0
# --------------------------------------------------
# Sentence: This is THE best course!!!
# Total Tokens: 4
# Unique Tokens: 4
# Average Token Length: 4.25
# --------------------------------------------------
# Sentence: Visit https://openai.com now!
# Total Tokens: 2
# Unique Tokens: 2
# Average Token Length: 4.0
# --------------------------------------------------
# ...

# %% [markdown]
# #Task 5: Frequency Analysis

# %%
from collections import Counter

all_tokens = []

for text in test_sentences:
    tokens, _ = preprocess_text(text)
    all_tokens.extend(tokens)

counter = Counter(all_tokens)

print("Top 10 frequent words:")
print(counter.most_common(10))

print("\nLeast 5 frequent words:")
print(counter.most_common()[-5:])
# Out:
# Top 10 frequent words:
# [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('looved', 1), ('product', 1), ('worst', 1), ('service', 1)]
#
# Least 5 frequent words:
# [('limited', 1), ('offer', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %% [markdown]
# # Task 6: Build Full Pipeline

# %%
def full_pipeline(text_list):
    all_tokens = []
    clean_sentences = []

    for text in text_list:
        tokens, clean = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(clean)

    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }


# Test full pipeline
output = full_pipeline(test_sentences)

print("\n===== Full Pipeline Output =====\n")
print(output)
# Out:
# ===== Full Pipeline Output =====
#
# {'tokens': ['get', 'free', 'access', 'now', 'absolutely', 'looved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'noo', 'this', 'baad', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'this'], 'clean_sentences': ['get free access now', 'absolutely looved this product', 'worst service ever', 'call', 'this the best course', 'visit now', 'noo this baad', 'got', 'win now limited offer', 'not happy with this']}

# %% [markdown]
# # Task 7: Error Handling

# %%
edge_cases = ["", "😍😍😍", "123456789", None]

print("\n===== Error Handling Tests =====\n")

for case in edge_cases:
    tokens, clean = preprocess_text(case)
    print(f"Input: {case}")
    print(f"Tokens: {tokens}")
    print(f"Cleaned: {clean}")
    print("-"*40)
# Out:
# ===== Error Handling Tests =====
#
# Input:
# Tokens: []
# Cleaned:
# ----------------------------------------
# Input: 😍😍😍
# Tokens: []
# Cleaned:
# ----------------------------------------
# Input: 123456789
# Tokens: []
# Cleaned:
# ----------------------------------------
# Input: None
# Tokens: []
# Cleaned:
# ----------------------------------------
